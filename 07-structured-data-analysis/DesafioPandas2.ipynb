# %% [markdown]
# ## Selecionando por índice

# %% [markdown]
# E se eu quiser pegar os valores de uma linha específica do dataframe?

# %%
import pandas as pd
multiple_choice = pd.read_csv('/home/cintia/workspace/tera-datascience-out2018/07-structured-data-analysis/multipleChoiceResponses.csv', encoding='ISO-8859-1')
free_form = pd.read_csv('/home/cintia/workspace/tera-datascience-out2018/07-structured-data-analysis/freeformResponses.csv', encoding='ISO-8859-1')
# Out:
# /home/cintia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/cintia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,17,21,38,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Qual comando eu usaria para pegar o registro da linha 11?
multiple_choice.iloc[10,]
# Out:
# GenderSelect                                                                          Female
# Country                                                                               Russia
# Age                                                                                       20
# EmploymentStatus                                      Not employed, and not looking for work
# StudentStatus                                                                            Yes
# LearningDataScience                        Yes, I'm focused on learning mostly data scien...
# CodeWriter                                                                               NaN
# CareerSwitcher                                                                           NaN
# CurrentJobTitleSelect                                                                    NaN
# TitleFit                                                                                 NaN
# CurrentEmployerType                                                                      NaN
# MLToolNextYearSelect                                                                  Python
# MLMethodNextYearSelect                                                           Neural Nets
# LanguageRecommendationSelect                                                          Python
# PublicDatasetsSelect                       Dataset aggregator/platform (i.e. Socrata/Kagg...
# LearningPlatformSelect                                                 Kaggle,Online courses
# LearningPlatformUsefulnessArxiv                                                          NaN
# LearningPlatformUsefulnessBlogs                                                          NaN
# LearningPlatformUsefulnessCollege                                                        NaN
# LearningPlatformUsefulnessCompany                                                        NaN
# LearningPlatformUsefulnessConferences                                                    NaN
# LearningPlatformUsefulnessFriends                                                        NaN
# LearningPlatformUsefulnessKaggle                                                 Very useful
# LearningPlatformUsefulnessNewsletters                                                    NaN
# LearningPlatformUsefulnessCommunities                                                    NaN
# LearningPlatformUsefulnessDocumentation                                                  NaN
# LearningPlatformUsefulnessCourses                                                Very useful
# LearningPlatformUsefulnessProjects                                                       NaN
# LearningPlatformUsefulnessPodcasts                                                       NaN
# LearningPlatformUsefulnessSO                                                             NaN
#                                                                  ...
# WorkMLTeamSeatSelect                                                                     NaN
# WorkDatasets                                                                             NaN
# WorkDatasetsChallenge                                                                    NaN
# WorkDataStorage                                                                          NaN
# WorkDataSharing                                                                          NaN
# WorkDataSourcing                                                                         NaN
# WorkCodeSharing                                                                          NaN
# RemoteWork                                                                               NaN
# CompensationAmount                                                                       NaN
# CompensationCurrency                                                                     NaN
# SalaryChange                                                                             NaN
# JobSatisfaction                                                                          NaN
# JobSearchResource                                                    Tech-specific job board
# JobHuntTime                                                                                0
# JobFactorLearning                                                             Very Important
# JobFactorSalary                                                           Somewhat important
# JobFactorOffice                                                           Somewhat important
# JobFactorLanguages                                                        Somewhat important
# JobFactorCommute                                                          Somewhat important
# JobFactorManagement                                                       Somewhat important
# JobFactorExperienceLevel                                                  Somewhat important
# JobFactorDepartment                                                           Very Important
# JobFactorTitle                                                                Very Important
# JobFactorCompanyFunding                                                   Somewhat important
# JobFactorImpact                                                               Very Important
# JobFactorRemote                                                           Somewhat important
# JobFactorIndustry                                                             Very Important
# JobFactorLeaderReputation                                                     Very Important
# JobFactorDiversity                                                        Somewhat important
# JobFactorPublishingOpportunity                                            Somewhat important
# Name: 10, Length: 228, dtype: object

# %% [markdown]
# Também posso ver só o valor de uma coluna, sem escrever o nome, somente pela sua posição

# %%
# E para pegar a primeira coluna do dataset?
multiple_choice.iloc[:, 0]
# Out:
# 0        Non-binary, genderqueer, or gender non-conforming
# 1                                                   Female
# 2                                                     Male
# 3                                                     Male
# 4                                                     Male
# 5                                                     Male
# 6                                                     Male
# 7                                                   Female
# 8                                                   Female
# 9                                                     Male
# 10                                                  Female
# 11                                                    Male
# 12                                                    Male
# 13                                                    Male
# 14                                                    Male
# 15                                                    Male
# 16                                                    Male
# 17                                                    Male
# 18                                                    Male
# 19                                                    Male
# 20                                                    Male
# 21                                                    Male
# 22                                                    Male
# 23                                                    Male
# 24                                                    Male
# 25                                                    Male
# 26                                                    Male
# 27                                                    Male
# 28                                                    Male
# 29                                                  Female
#                                ...
# 16686                                                 Male
# 16687                                                 Male
# 16688                                               Female
# 16689                                               Female
# 16690                                                 Male
# 16691                                                 Male
# 16692                                                 Male
# 16693                                                 Male
# 16694                                                 Male
# 16695                                                 Male
# 16696                                                 Male
# 16697                                                 Male
# 16698                                                 Male
# 16699                                                 Male
# 16700                                                 Male
# 16701                                                 Male
# 16702                                                 Male
# 16703                                                 Male
# 16704                                                 Male
# 16705                                                 Male
# 16706                                                 Male
# 16707                                               Female
# 16708                                                 Male
# 16709                                                 Male
# 16710                                                 Male
# 16711                                               Female
# 16712                                                 Male
# 16713                                               Female
# 16714                                               Female
# 16715                                                 Male
# Name: GenderSelect, Length: 16716, dtype: object

# %% [markdown]
# Mais detalhes sobre `loc`, `iloc` e `ix` podem ser vistas nesse [link](https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/)

# %% [markdown]
# ### Desafio 2

# %% [markdown]
# Será que temos uma quantidade gigante de nulos nesse dataset porque as pessoas não preencheram essas perguntas por multipla escolha ou por que responderam no modo livre?
#
# Para validar essa hipótese teremos que carregar o outro dataset, que contém as respostas das perguntas em forma livre e juntar (Pelo menos uma das variáveis) dos dois os datasets. Eu escolhi `DataScienceIdentity`

# %% [markdown]
# ![challenge_panda](https://media.giphy.com/media/K9z3im98oo9Ve/giphy.gif)

# %%
# a ideia do desafio é verificar se quando o índice de um dataset tem resposta no outro dataset esse índice é nulo
ds_multiple = multiple_choice['DataScienceIdentitySelect']
ds_free = free_form['DataScienceIdentityFreeForm']
#- Ou seja: Vamos comparar as linhas dos datasets
multiple = ds_multiple.notnull().sum()
print('multiple', multiple)
free = ds_free.notnull().sum()
print('free', free)
print('sum', multiple + free)
compare = free | multiple
print('compare', compare)

print(len(ds_multiple), len(ds_free))
# Out:
# multiple 12671
# free 2417
# sum 15088
# compare 14719
# 16716 16716

# %%
pd.DataFrame({
    'Multiple': ds_multiple,
    'Free': ds_free})
# Out:
#                      Multiple  \
# 0                         Yes
# 1                         Yes
# 2                         Yes
# 3                         Yes
# 4                          No
# 5                         NaN
# 6                          No
# 7                          No
# 8                          No
# 9      Sort of (Explain more)
# 10                         No
# 11                        NaN
# 12                         No
# 13                        NaN
# 14                         No
# 15                        Yes
# 16                        NaN
# 17                        NaN
# 18     Sort of (Explain more)
# 19     Sort of (Explain more)
# 20                        Yes
# 21                        Yes
# 22                         No
# 23     Sort of (Explain more)
# 24                         No
# 25                        Yes
# 26                        Yes
# 27                        NaN
# 28                        NaN
# 29                        Yes
# ...                       ...
# 16686                      No
# 16687  Sort of (Explain more)
# 16688                      No
# 16689                      No
# 16690                      No
# 16691                      No
# 16692                     Yes
# 16693                      No
# 16694                     NaN
# 16695                     Yes
# 16696                      No
# 16697                      No
# 16698                     Yes
# 16699                     NaN
# 16700                     NaN
# 16701                     NaN
# 16702                      No
# 16703                     Yes
# 16704                     Yes
# 16705                     Yes
# 16706                     Yes
# 16707                     NaN
# 16708                     NaN
# 16709                     Yes
# 16710                     Yes
# 16711                      No
# 16712                      No
# 16713                     NaN
# 16714                     Yes
# 16715                     Yes
#
#                                                     Free
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      I use mid-level data science paired with high-...
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10     My job is a combination of software design and...
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15     Consider myself an amateur/aspiring data scien...
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                               not yet
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 16686                                                NaN
# 16687                                                NaN
# 16688                                                NaN
# 16689                                                NaN
# 16690                                                NaN
# 16691                                                NaN
# 16692                                                NaN
# 16693                                                NaN
# 16694  Was professor and employed many DS techniques;...
# 16695                                                NaN
# 16696                                                NaN
# 16697          Stepping into the field of data science.
# 16698                                                NaN
# 16699                                                NaN
# 16700                                                NaN
# 16701  I think data scientist just use the existing a...
# 16702                                                NaN
# 16703                                                NaN
# 16704                                                NaN
# 16705                                                NaN
# 16706                                                NaN
# 16707                                                NaN
# 16708                                                NaN
# 16709                                                NaN
# 16710  Do a lot of data analysis either for M&A activ...
# 16711                                                NaN
# 16712                                                NaN
# 16713                                                NaN
# 16714                                                NaN
# 16715                                                NaN
#
# [16716 rows x 2 columns]

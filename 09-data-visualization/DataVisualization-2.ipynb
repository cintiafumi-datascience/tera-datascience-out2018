# %% [markdown]
# # Visualização de dados para tomada de decisão

# %% [markdown]
# ![](https://media.giphy.com/media/zw69pUViBZCZW/giphy.gif)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import re
# %matplotlib inline

# %%
df = pd.read_csv('multipleChoiceResponses.csv', encoding="ISO-8859-1")
# Out:
# /home/cintia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Quais são as áreas de graduação dos cientistas de dados?

# %%
#Countplot com MajorSelect
sns.countplot(y='MajorSelect', data=df, palette='Greens_d').set_title('Count Major')
# Out:
# Text(0.5,1,'Count Major')

# %% [markdown]
# Para ficar mais facil de ver podemos ordenar as barras

# %%
# ordene o eixo y
_ = sns.countplot(y='MajorSelect', data=df, palette="Greens_d", order=df['MajorSelect'].value_counts().index).set_title('Count Major')

# %% [markdown]
# Agora ficou bem mais fácil de tirar conclusões sobre os cursos.
#
# A maioria dos cientistas de dados estudou ciência da computação, matemática ou engenharia.

# %% [markdown]
# E se trocarmos os y por um x?

# %% [markdown]
# ### Qual o maior grau de educação dos cientistas de dados?

# %%
# Use o campo FormalEducation
_ = sns.countplot(y='FormalEducation', data=df, palette='Greens_d', 
                  order=df['FormalEducation'].value_counts().index).set_title('Count Major')

# %% [markdown]
# ### Desafio 2
# ##### Quais os empregos anteriores dos cientistas de dados?
#
# Para fazer esse desafio você vai consultar a coluna `PastJobTitlesSelect`. Veja que essa coluna possui varios valores. Você precisará criar um método para reduzir a granularidade dessa coluna.

# %% [markdown]
# Dica: A solução fica mais fácil se você usar [expressões regulares](https://pt.wikipedia.org/wiki/Express%C3%A3o_regular). Para testá-las use [esse site](https://regexr.com/)

# %% [markdown]
# ![finn_mathematical](https://media.giphy.com/media/ccQ8MSKkjHE2c/giphy.gif)

# %%
# Resolva o desafio aqui
df['PastJobTitlesSelect'].value_counts()
# Out:
# I haven't started working yet                                                                                                                                                                                    1454
# Other                                                                                                                                                                                                            1043
# Researcher                                                                                                                                                                                                        786
# Software Developer/Software Engineer                                                                                                                                                                              784
# Engineer                                                                                                                                                                                                          497
# Programmer,Software Developer/Software Engineer                                                                                                                                                                   379
# Programmer                                                                                                                                                                                                        372
# Data Analyst                                                                                                                                                                                                      353
# Business Analyst                                                                                                                                                                                                  340
# Data Scientist                                                                                                                                                                                                    210
# Business Analyst,Data Analyst                                                                                                                                                                                     194
# Engineer,Programmer,Software Developer/Software Engineer                                                                                                                                                          143
# Engineer,Researcher                                                                                                                                                                                               138
# Researcher,Other                                                                                                                                                                                                  131
# Statistician                                                                                                                                                                                                      125
# Computer Scientist                                                                                                                                                                                                121
# Business Analyst,Other                                                                                                                                                                                            119
# Data Scientist,Researcher                                                                                                                                                                                         109
# Researcher,Software Developer/Software Engineer                                                                                                                                                                   105
# Data Analyst,Researcher                                                                                                                                                                                            99
# Data Analyst,Other                                                                                                                                                                                                 90
# Engineer,Programmer                                                                                                                                                                                                83
# Data Analyst,Data Scientist                                                                                                                                                                                        76
# DBA/Database Engineer,Programmer,Software Developer/Software Engineer                                                                                                                                              75
# Engineer,Software Developer/Software Engineer                                                                                                                                                                      72
# DBA/Database Engineer                                                                                                                                                                                              63
# Software Developer/Software Engineer,Other                                                                                                                                                                         63
# Engineer,Other                                                                                                                                                                                                     62
# Programmer,Researcher                                                                                                                                                                                              62
# Computer Scientist,Programmer,Software Developer/Software Engineer                                                                                                                                                 62
#                                                                                                                                                                                                                  ...
# Computer Scientist,Data Analyst,Data Miner,Operations Research Practitioner,Predictive Modeler,Researcher,Statistician                                                                                              1
# Business Analyst,Computer Scientist,DBA/Database Engineer                                                                                                                                                           1
# Business Analyst,Data Analyst,Researcher,Statistician,Other                                                                                                                                                         1
# Data Scientist,Software Developer/Software Engineer,Statistician,Other                                                                                                                                              1
# Machine Learning Engineer,Operations Research Practitioner,Researcher                                                                                                                                               1
# Data Analyst,Engineer,Predictive Modeler                                                                                                                                                                            1
# Computer Scientist,Data Analyst,Data Miner,DBA/Database Engineer,Programmer,Researcher                                                                                                                              1
# Computer Scientist,Programmer,Software Developer/Software Engineer,Statistician                                                                                                                                     1
# Data Analyst,Operations Research Practitioner,Software Developer/Software Engineer                                                                                                                                  1
# Business Analyst,Data Analyst,Data Scientist,Engineer,Other                                                                                                                                                         1
# Business Analyst,Computer Scientist,Data Scientist,Engineer,Researcher,Software Developer/Software Engineer                                                                                                         1
# Data Scientist,DBA/Database Engineer,Engineer,Researcher                                                                                                                                                            1
# Computer Scientist,Engineer,Machine Learning Engineer,Predictive Modeler,Programmer,Software Developer/Software Engineer                                                                                            1
# Computer Scientist,Machine Learning Engineer,Other                                                                                                                                                                  1
# Business Analyst,Data Miner,Data Scientist,DBA/Database Engineer,Machine Learning Engineer,Programmer,Software Developer/Software Engineer                                                                          1
# Business Analyst,Data Analyst,Data Miner,Data Scientist,Predictive Modeler,Software Developer/Software Engineer                                                                                                     1
# Computer Scientist,Data Analyst,Data Scientist,Engineer,Programmer,Researcher,Software Developer/Software Engineer                                                                                                  1
# Business Analyst,Data Analyst,Data Miner,Data Scientist,Machine Learning Engineer,Operations Research Practitioner,Researcher                                                                                       1
# DBA/Database Engineer,Engineer,Programmer,Software Developer/Software Engineer,Statistician                                                                                                                         1
# Business Analyst,Data Analyst,Data Miner,Data Scientist,Predictive Modeler,Programmer,Statistician                                                                                                                  1
# Business Analyst,Computer Scientist,Data Analyst,Data Scientist,Researcher,Software Developer/Software Engineer                                                                                                     1
# Business Analyst,Computer Scientist,Data Analyst,Data Miner,Engineer,Machine Learning Engineer,Operations Research Practitioner,Predictive Modeler,Programmer,Researcher,Software Developer/Software Engineer       1
# Computer Scientist,Data Analyst,DBA/Database Engineer,Engineer,Programmer,Software Developer/Software Engineer,Other                                                                                                1
# Business Analyst,Engineer,Programmer,Software Developer/Software Engineer,Other                                                                                                                                     1
# Computer Scientist,Data Miner,DBA/Database Engineer,Researcher,Software Developer/Software Engineer                                                                                                                 1
# Predictive Modeler,Programmer,Software Developer/Software Engineer                                                                                                                                                  1
# Business Analyst,Data Analyst,Data Miner,Data Scientist,Engineer,Predictive Modeler,Statistician                                                                                                                    1
# Business Analyst,Computer Scientist,DBA/Database Engineer,Programmer                                                                                                                                                1
# Business Analyst,Data Analyst,Operations Research Practitioner,Predictive Modeler,Researcher,Statistician,Other                                                                                                     1
# Business Analyst,Computer Scientist,Data Analyst,Data Miner,Data Scientist,DBA/Database Engineer,Engineer,Machine Learning Engineer,Programmer,Researcher,Software Developer/Software Engineer                      1
# Name: PastJobTitlesSelect, Length: 1855, dtype: int64

# %%
print(df['PastJobTitlesSelect'][0])
# Out:
# Predictive Modeler,Programmer,Researcher

# %%
print(re.sub(r'(?=,).*', '', df['PastJobTitlesSelect'][0]))
# Out:
# Predictive Modeler

# %%
df['PastJobTitlesSelect'] = df['PastJobTitlesSelect'].fillna('null')
df['PastJobTitles'] = df['PastJobTitlesSelect'].apply(lambda x: re.sub(r'(?=,).*', '', x))

# %%
df['PastJobTitles'].value_counts()
# Out:
# null                                    2524
# Business Analyst                        2338
# Data Analyst                            1806
# I haven't started working yet           1454
# Engineer                                1302
# Computer Scientist                      1232
# Researcher                              1125
# Other                                   1083
# Programmer                              1002
# Data Scientist                           935
# Software Developer/Software Engineer     861
# DBA/Database Engineer                    326
# Data Miner                               212
# Machine Learning Engineer                202
# Statistician                             146
# Predictive Modeler                        85
# Operations Research Practitioner          83
# Name: PastJobTitles, dtype: int64

# %%
df[['PastJobTitles', 'PastJobTitlesSelect']].head(10)
# Out:
#                           PastJobTitles  \
# 0                    Predictive Modeler
# 1  Software Developer/Software Engineer
# 2                        Data Scientist
# 3                      Business Analyst
# 4                    Computer Scientist
# 5                          Data Analyst
# 6                    Computer Scientist
# 7  Software Developer/Software Engineer
# 8                      Business Analyst
# 9  Software Developer/Software Engineer
#
#                                  PastJobTitlesSelect
# 0           Predictive Modeler,Programmer,Researcher
# 1               Software Developer/Software Engineer
# 2           Data Scientist,Machine Learning Engineer
# 3  Business Analyst,Operations Research Practitio...
# 4  Computer Scientist,Data Analyst,Data Miner,Dat...
# 5             Data Analyst,Engineer,Researcher,Other
# 6  Computer Scientist,DBA/Database Engineer,Engin...
# 7               Software Developer/Software Engineer
# 8                                   Business Analyst
# 9               Software Developer/Software Engineer

# %%
_ = sns.countplot(y=df['PastJobTitles'], 
                  data=df, 
                  order=df['PastJobTitles'].value_counts().index).set_title('Previous job')
